# %% [markdown]
# ## 네이버 검색 API 활용

# %%
# API 접근을 위한 클라이언트 정보 설정
client_id = "6QnAnyNCAYrwWxZxbfI5" 
client_secret = "XvhXEE3D74"

# %%
import os
os.chdir(r"C:\Users\lizzy\스파르타_파이썬\웹크롤링")
print(os.getcwd())  # 잘 바뀌었는지 확인
# Out:
# C:\Users\lizzy\스파르타_파이썬\심화플젝

# %% [markdown]
# ### 블로그 검색
# [블로그 API 문서 링크](https://developers.naver.com/docs/serviceapi/search/blog/blog.md#%EB%B8%94%EB%A1%9C%EA%B7%B8)
#
# (1) 네이버 개발자 센터에서 제공하는 기본 코드

# %%
import os
import sys
import urllib.request
encText = urllib.parse.quote("고양이") #UTF-8
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Fri, 24 Oct 2025 17:24:04 +0900",
# 	"total":11802673,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"수원<b>고양이<\/b>분양 예비 집사 안내서",
# 			"link":"https:\/\/blog.naver.com\/hotelelena\/224051074380",
# 			"description":"<b>고양이<\/b> 가족 맞이 결심한 계기 자취 생활이 길어지면서 집에 돌아오는 게 외로웠어요. 동네 산책 중 만난 <b>고양이<\/b>들 보면서 '나도 이런 친구와 함께하면 좋겠다' 싶었죠. 특히 <b>고양이<\/b>의 독립적인 매력이 강아지와... ",
# 			"bloggername":"포메라니안분양 토이푸들분양",
# 			"bloggerlink":"blog.naver.com\/hotelelena",
# 			"postdate":"20251023"
# 		},
# 		{
# 			"title":"보령<b>고양이<\/b>분양 진심이 느껴지던 미유펫",
# 			"link":"https:\/\/blog.naver.com\/surfingtaiji\/224050970774",
# 			"description":"하지만 아무래도 특별한 관리가 필요하다는 얘기를 많이 들었기에 보령<b>고양이<\/b>분양 결정을 내리기까지... 스핑크스의 낯설지만 매력적인 첫인상 1) 생각보다 따뜻하고 부드러워요 보령<b>고양이<\/b>분양을 받기 전... ",
# 			"bloggername":"쨘쨔자잔쨔자쟌! 두둥!",
# 			"bloggerlink":"blog.naver.com\/surfingtaiji",
# 			"postdate":"20251023"
# 		},
# 		{
# 			"title":"<b>고양이<\/b> 모래 먼지 차단 노하우 공개",
# 			"link":"https:\/\/blog.naver.com\/gosoo777\/224052520223",
# 			"description":"이번 여름, <b>고양이<\/b> 모래 먼지 때문에 어찌나 고생을 했는지 몰라요. 아무리 화장실 청소를 꼼꼼하게 해도 며칠 지나지 않아서 좋지 않은 냄새와 먼지가 스멀스멀 올라왔거든요. <b>고양이<\/b> 커뮤니티에 물어보면서... ",
# 			"bloggername":"댕댕이스토리-댕댕이들의 소소한 일상 이야기 그리고",
# 			"bloggerlink":"blog.naver.com\/gosoo777",
# 			"postdate":"20251024"
# 		},
# 		{
# 			"title":"<b>고양이<\/b> 싸움, 성격 차이에서 오는 갈등과 해결법",
# 			"link":"https:\/\/blog.naver.com\/sil07312\/224052017358",
# 			"description":"하나는 <b>고양이<\/b>들 사이에서 하악! 소리와 함께 엉겨 붙어 싸움이 벌어질 때인데 저희집 삼냥이들도 예외는 아니에요 평화롭다가도 한순간에 난리부르스~ 막내 구우는 집사보다 형제 <b>고양이<\/b>를 더 좋아하고 애정... ",
# 			"bloggername":"그냥저냥",
# 			"bloggerlink":"blog.naver.com\/sil07312",
# 			"postdate":"20251024"
# 		},
# 		{
# 			"title":"모모의 <b>고양이<\/b>호텔 - 나루",
# 			"link":"https:\/\/blog.naver.com\/karon0000\/224052432571",
# 			"description":"[모모의<b>고양이<\/b>호텔] 안녕하세요 편안한 <b>고양이<\/b>들의 쉼터 모모의<b>고양이<\/b>호텔 파출부 입니다. 9월 가을에 보름간 호텔에서 지내고 가신 노랑둥이 똑똑냥 나루 !!! 노랑둥이 나루님 ~~ 집안에 인테리어 공사 때문에... ",
# 			"bloggername":"모모의 고양이호텔",
# 			"bloggerlink":"blog.naver.com\/karon0000",
# 			"postdate":"20251024"
# 		},
# 		{
# 			"title":"<b>고양이<\/b>츄르추천 맛있는 <b>고양이<\/b>영양제 묘진단",
# 			"link":"https:\/\/blog.naver.com\/noonicty\/224051812558",
# 			"description":"챙겨주는 <b>고양이<\/b>영양제가 여러 가지예요 처음엔 좋은 성분만 생각해서 이것저것 사다 보니 하루에도 여러 가지를 나눠 먹이는 게 꽤 번거롭더라구요 그래서 <b>고양이<\/b>츄르처럼 편하게 급여할 수 있는... ",
# 			"bloggername":"참치누나와 벵이랑스토리",
# 			"bloggerlink":"blog.naver.com\/noonicty",
# 			"postdate":"20251024"
# 		},
# 		{
# 			"title":"<b>고양이<\/b> 모래 먼지 줄이는 현실적인 방법",
# 			"link":"https:\/\/blog.naver.com\/morningstar7\/224051435749",
# 			"description":"<b>고양이<\/b>모래중 먼지 날림 없고 냄새 잡는 탈취력까지 좋은 모래 찾고 계신 집사님이라면 오늘 그 고민... 드릴게요 <b>고양이<\/b>모래를 고를때 먼지와 탈취력이 가장 큰 고민이지 않나요?!! <b>고양이<\/b>화장실 청소하다 보면... ",
# 			"bloggername":"고양이집사 채연맘",
# 			"bloggerlink":"blog.naver.com\/morningstar7",
# 			"postdate":"20251023"
# 		},
# 		{
# 			"title":"<b>고양이<\/b> 신장관리, 페노비스 유산균 하루 한 포!",
# 			"link":"https:\/\/blog.naver.com\/borumi0312\/224052525520",
# 			"description":"페노비스에서 만든 <b>고양이<\/b> 신장관리 유산균인데요. 17살 희동이는 (신부전까지는 아니지만)... 변비도 약간 있어서 고민일 때가 많은데 마침 신장과 장에 모두 도움을 줄 수 있는 <b>고양이<\/b> 영양제가 있다 해서... ",
# 			"bloggername":"고양이 집사의 세계여행",
# 			"bloggerlink":"blog.naver.com\/borumi0312",
# 			"postdate":"20251024"
# 		},
# 		{
# 			"title":"<b>고양이<\/b> 화장실 배변실수 원인 배변훈련 스프레이?",
# 			"link":"https:\/\/blog.naver.com\/djsvh123\/224051043656",
# 			"description":"<b>고양이<\/b> 화장실 배변실수 원인 배변훈련 스프레이? 우리 집 <b>고양이<\/b> 화장실도 잘 가던 아이가 갑작스럽게 아무 데나 소변을 보니 당황스럽죠, 문제는 <b>고양이<\/b> 배변실수 원인은 단순한 버릇 문제가 아닌 환경, 심리... ",
# 			"bloggername":"리리남매의 하루",
# 			"bloggerlink":"blog.naver.com\/djsvh123",
# 			"postdate":"20251023"
# 		},
# 		{
# 			"title":"강아지 <b>고양이<\/b> 귤 먹어도 알레르기 괜찮을까?",
# 			"link":"https:\/\/blog.naver.com\/pcmm1\/224050533989",
# 			"description":"오늘은 <b>고양이<\/b>귤, 강아지귤 먹어도 되는지, 그리고, 강아지귤알레르기 괜찮은지에 대해... 반드시 생귤 과육만 주세요 <b>고양이<\/b> 귤 먹어도 되나요? YES <b>고양이<\/b> 귤 급여는 가능합니다. 하지만 대부분의 <b>고양이<\/b>는... ",
# 			"bloggername":"사월&영웅이와 행복한 동행",
# 			"bloggerlink":"blog.naver.com\/pcmm1",
# 			"postdate":"20251023"
# 		}
# 	]
# }

# %% [markdown]
# (2) requests 라이브러리를 통한 호출

# %%
# requests 라이브러리 임포트
import requests
from urllib.parse import quote

# 검색어 설정
search_query = "고양이"

# API 기본 URL
base_url = "https://openapi.naver.com/v1/search/blog"

# API 요청 헤더 설정
headers = {
    "X-Naver-Client-Id": client_id,
    "X-Naver-Client-Secret": client_secret
}

# API 요청 파라미터 설정
params = {
    "query": search_query,     # 검색어
    "display": 10,             # 검색 결과 출력 건수 (기본값: 10, 최대: 100)
    "start": 1,                # 검색 시작 위치 (기본값: 1, 최대: 1000)
    "sort": "sim"              # 정렬 방식 - sim: 정확도순, date: 날짜순
}


# GET 요청 보내기 (params 딕셔너리 사용)
response = requests.get( # 한글 자동으로 UTF-8인코딩 함
    base_url,
    headers=headers,
    params=params
)

# 응답 상태 코드 확인 및 결과 출력
if response.status_code == 200:
    # JSON 형식으로 응답 데이터 파싱
    result = response.json()
    print(result)
        
    # 전체 검색 결과 수 출력
    print(f"총 검색 결과: {result['total']} 건")
    print(f"현재 페이지: {params['start']} / {result['total']}")
    print("-" * 50)
    
    # 검색 결과 출력
    for item in result.get('items', []):
        print(f"제목: {item['title']}")
        print(f"블로거: {item['bloggername']}")
        print(f"작성일: {item['postdate']}")
        print(f"링크: {item['link']}")
        print(f"설명: {item['description']}")
        print("-" * 50)
else:
    # 에러 발생시 상태 코드와 에러 메시지 출력
    print(f"Error Code: {response.status_code}")
    print(f"Error Message: {response.text}")
# Out:
# {'lastBuildDate': 'Fri, 24 Oct 2025 17:24:05 +0900', 'total': 11802673, 'start': 1, 'display': 10, 'items': [{'title': '수원<b>고양이</b>분양 예비 집사 안내서', 'link': 'https://blog.naver.com/hotelelena/224051074380', 'description': "<b>고양이</b> 가족 맞이 결심한 계기 자취 생활이 길어지면서 집에 돌아오는 게 외로웠어요. 동네 산책 중 만난 <b>고양이</b>들 보면서 '나도 이런 친구와 함께하면 좋겠다' 싶었죠. 특히 <b>고양이</b>의 독립적인 매력이 강아지와... ", 'bloggername': '포메라니안분양 토이푸들분양', 'bloggerlink': 'blog.naver.com/hotelelena', 'postdate': '20251023'}, {'title': '보령<b>고양이</b>분양 진심이 느껴지던 미유펫', 'link': 'https://blog.naver.com/surfingtaiji/224050970774', 'description': '하지만 아무래도 특별한 관리가 필요하다는 얘기를 많이 들었기에 보령<b>고양이</b>분양 결정을 내리기까지... 스핑크스의 낯설지만 매력적인 첫인상 1) 생각보다 따뜻하고 부드러워요 보령<b>고양이</b>분양을 받기 전... ', 'bloggername': '쨘쨔자잔쨔자쟌! 두둥!', 'bloggerlink': 'blog.naver.com/surfingtaiji', 'postdate': '20251023'}, {'title': '<b>고양이</b> 모래 먼지 차단 노하우 공개', 'link': 'https://blog.naver.com/gosoo777/224052520223', 'description': '이번 여름, <b>고양이</b> 모래 먼지 때문에 어찌나 고생을 했는지 몰라요. 아무리 화장실 청소를 꼼꼼하게 해도 며칠 지나지 않아서 좋지 않은 냄새와 먼지가 스멀스멀 올라왔거든요. <b>고양이</b> 커뮤니티에 물어보면서... ', 'bloggername': '댕댕이스토리-댕댕이들의 소소한 일상 이야기 그리고', 'bloggerlink': 'blog.naver.com/gosoo777', 'postdate': '20251024'}, {'title': '<b>고양이</b> 싸움, 성격 차이에서 오는 갈등과 해결법', 'link': 'https://blog.naver.com/sil07312/224052017358', 'description': '하나는 <b>고양이</b>들 사이에서 하악! 소리와 함께 엉겨 붙어 싸움이 벌어질 때인데 저희집 삼냥이들도 예외는 아니에요 평화롭다가도 한순간에 난리부르스~ 막내 구우는 집사보다 형제 <b>고양이</b>를 더 좋아하고 애정... ', 'bloggername': '그냥저냥', 'bloggerlink': 'blog.naver.com/sil07312', 'postdate': '20251024'}, {'title': '모모의 <b>고양이</b>호텔 - 나루', 'link': 'https://blog.naver.com/karon0000/224052432571', 'description': '[모모의<b>고양이</b>호텔] 안녕하세요 편안한 <b>고양이</b>들의 쉼터 모모의<b>고양이</b>호텔 파출부 입니다. 9월 가을에 보름간 호텔에서 지내고 가신 노랑둥이 똑똑냥 나루 !!! 노랑둥이 나루님 ~~ 집안에 인테리어 공사 때문에... ', 'bloggername': '모모의 고양이호텔', 'bloggerlink': 'blog.naver.com/karon0000', 'postdate': '20251024'}, {'title': '<b>고양이</b>츄르추천 맛있는 <b>고양이</b>영양제 묘진단', 'link': 'https://blog.naver.com/noonicty/224051812558', 'description': '챙겨주는 <b>고양이</b>영양제가 여러 가지예요 처음엔 좋은 성분만 생각해서 이것저것 사다 보니 하루에도 여러 가지를 나눠 먹이는 게 꽤 번거롭더라구요 그래서 <b>고양이</b>츄르처럼 편하게 급여할 수 있는... ', 'bloggername': '참치누나와 벵이랑스토리', 'bloggerlink': 'blog.naver.com/noonicty', 'postdate': '20251024'}, {'title': '<b>고양이</b> 모래 먼지 줄이는 현실적인 방법', 'link': 'https://blog.naver.com/morningstar7/224051435749', 'description': '<b>고양이</b>모래중 먼지 날림 없고 냄새 잡는 탈취력까지 좋은 모래 찾고 계신 집사님이라면 오늘 그 고민... 드릴게요 <b>고양이</b>모래를 고를때 먼지와 탈취력이 가장 큰 고민이지 않나요?!! <b>고양이</b>화장실 청소하다 보면... ', 'bloggername': '고양이집사 채연맘', 'bloggerlink': 'blog.naver.com/morningstar7', 'postdate': '20251023'}, {'title': '<b>고양이</b> 신장관리, 페노비스 유산균 하루 한 포!', 'link': 'https://blog.naver.com/borumi0312/224052525520', 'description': '페노비스에서 만든 <b>고양이</b> 신장관리 유산균인데요. 17살 희동이는 (신부전까지는 아니지만)... 변비도 약간 있어서 고민일 때가 많은데 마침 신장과 장에 모두 도움을 줄 수 있는 <b>고양이</b> 영양제가 있다 해서... ', 'bloggername': '고양이 집사의 세계여행', 'bloggerlink': 'blog.naver.com/borumi0312', 'postdate': '20251024'}, {'title': '<b>고양이</b> 화장실 배변실수 원인 배변훈련 스프레이?', 'link': 'https://blog.naver.com/djsvh123/224051043656', 'description': '<b>고양이</b> 화장실 배변실수 원인 배변훈련 스프레이? 우리 집 <b>고양이</b> 화장실도 잘 가던 아이가 갑작스럽게 아무 데나 소변을 보니 당황스럽죠, 문제는 <b>고양이</b> 배변실수 원인은 단순한 버릇 문제가 아닌 환경, 심리... ', 'bloggername': '리리남매의 하루', 'bloggerlink': 'blog.naver.com/djsvh123', 'postdate': '20251023'}, {'title': '강아지 <b>고양이</b> 귤 먹어도 알레르기 괜찮을까?', 'link': 'https://blog.naver.com/pcmm1/224050533989', 'description': '오늘은 <b>고양이</b>귤, 강아지귤 먹어도 되는지, 그리고, 강아지귤알레르기 괜찮은지에 대해... 반드시 생귤 과육만 주세요 <b>고양이</b> 귤 먹어도 되나요? YES <b>고양이</b> 귤 급여는 가능합니다. 하지만 대부분의 <b>고양이</b>는... ', 'bloggername': '사월&영웅이와 행복한 동행', 'bloggerlink': 'blog.naver.com/pcmm1', 'postdate': '20251023'}]}
# 총 검색 결과: 11802673 건
# 현재 페이지: 1 / 11802673
# --------------------------------------------------
# 제목: 수원<b>고양이</b>분양 예비 집사 안내서
# 블로거: 포메라니안분양 토이푸들분양
# 작성일: 20251023
# 링크: https://blog.naver.com/hotelelena/224051074380
# 설명: <b>고양이</b> 가족 맞이 결심한 계기 자취 생활이 길어지면서 집에 돌아오는 게 외로웠어요. 동네 산책 중 만난 <b>고양이</b>들 보면서 '나도 이런 친구와 함께하면 좋겠다' 싶었죠. 특히 <b>고양이</b>의 독립적인 매력이 강아지와...
# --------------------------------------------------
# 제목: 보령<b>고양이</b>분양 진심이 느껴지던 미유펫
# 블로거: 쨘쨔자잔쨔자쟌! 두둥!
# 작성일: 20251023
# 링크: https://blog.naver.com/surfingtaiji/224050970774
# 설명: 하지만 아무래도 특별한 관리가 필요하다는 얘기를 많이 들었기에 보령<b>고양이</b>분양 결정을 내리기까지... 스핑크스의 낯설지만 매력적인 첫인상 1) 생각보다 따뜻하고 부드러워요 보령<b>고양이</b>분양을 받기 전...
# --------------------------------------------------
# 제목: <b>고양이</b> 모래 먼지 차단 노하우 공개
# 블로거: 댕댕이스토리-댕댕이들의 소소한 일상 이야기 그리고
# 작성일: 20251024
# 링크: https://blog.naver.com/gosoo777/224052520223
# 설명: 이번 여름, <b>고양이</b> 모래 먼지 때문에 어찌나 고생을 했는지 몰라요. 아무리 화장실 청소를 꼼꼼하게 해도 며칠 지나지 않아서 좋지 않은 냄새와 먼지가 스멀스멀 올라왔거든요. <b>고양이</b> 커뮤니티에 물어보면서...
# --------------------------------------------------
# 제목: <b>고양이</b> 싸움, 성격 차이에서 오는 갈등과 해결법
# 블로거: 그냥저냥
# 작성일: 20251024
# 링크: https://blog.naver.com/sil07312/224052017358
# 설명: 하나는 <b>고양이</b>들 사이에서 하악! 소리와 함께 엉겨 붙어 싸움이 벌어질 때인데 저희집 삼냥이들도 예외는 아니에요 평화롭다가도 한순간에 난리부르스~ 막내 구우는 집사보다 형제 <b>고양이</b>를 더 좋아하고 애정...
# --------------------------------------------------
# 제목: 모모의 <b>고양이</b>호텔 - 나루
# 블로거: 모모의 고양이호텔
# 작성일: 20251024
# 링크: https://blog.naver.com/karon0000/224052432571
# 설명: [모모의<b>고양이</b>호텔] 안녕하세요 편안한 <b>고양이</b>들의 쉼터 모모의<b>고양이</b>호텔 파출부 입니다. 9월 가을에 보름간 호텔에서 지내고 가신 노랑둥이 똑똑냥 나루 !!! 노랑둥이 나루님 ~~ 집안에 인테리어 공사 때문에...
# --------------------------------------------------
# 제목: <b>고양이</b>츄르추천 맛있는 <b>고양이</b>영양제 묘진단
# 블로거: 참치누나와 벵이랑스토리
# 작성일: 20251024
# 링크: https://blog.naver.com/noonicty/224051812558
# 설명: 챙겨주는 <b>고양이</b>영양제가 여러 가지예요 처음엔 좋은 성분만 생각해서 이것저것 사다 보니 하루에도 여러 가지를 나눠 먹이는 게 꽤 번거롭더라구요 그래서 <b>고양이</b>츄르처럼 편하게 급여할 수 있는...
# --------------------------------------------------
# 제목: <b>고양이</b> 모래 먼지 줄이는 현실적인 방법
# 블로거: 고양이집사 채연맘
# 작성일: 20251023
# 링크: https://blog.naver.com/morningstar7/224051435749
# 설명: <b>고양이</b>모래중 먼지 날림 없고 냄새 잡는 탈취력까지 좋은 모래 찾고 계신 집사님이라면 오늘 그 고민... 드릴게요 <b>고양이</b>모래를 고를때 먼지와 탈취력이 가장 큰 고민이지 않나요?!! <b>고양이</b>화장실 청소하다 보면...
# --------------------------------------------------
# 제목: <b>고양이</b> 신장관리, 페노비스 유산균 하루 한 포!
# 블로거: 고양이 집사의 세계여행
# 작성일: 20251024
# 링크: https://blog.naver.com/borumi0312/224052525520
# 설명: 페노비스에서 만든 <b>고양이</b> 신장관리 유산균인데요. 17살 희동이는 (신부전까지는 아니지만)... 변비도 약간 있어서 고민일 때가 많은데 마침 신장과 장에 모두 도움을 줄 수 있는 <b>고양이</b> 영양제가 있다 해서...
# --------------------------------------------------
# 제목: <b>고양이</b> 화장실 배변실수 원인 배변훈련 스프레이?
# 블로거: 리리남매의 하루
# 작성일: 20251023
# 링크: https://blog.naver.com/djsvh123/224051043656
# 설명: <b>고양이</b> 화장실 배변실수 원인 배변훈련 스프레이? 우리 집 <b>고양이</b> 화장실도 잘 가던 아이가 갑작스럽게 아무 데나 소변을 보니 당황스럽죠, 문제는 <b>고양이</b> 배변실수 원인은 단순한 버릇 문제가 아닌 환경, 심리...
# --------------------------------------------------
# 제목: 강아지 <b>고양이</b> 귤 먹어도 알레르기 괜찮을까?
# 블로거: 사월&영웅이와 행복한 동행
# 작성일: 20251023
# 링크: https://blog.naver.com/pcmm1/224050533989
# 설명: 오늘은 <b>고양이</b>귤, 강아지귤 먹어도 되는지, 그리고, 강아지귤알레르기 괜찮은지에 대해... 반드시 생귤 과육만 주세요 <b>고양이</b> 귤 먹어도 되나요? YES <b>고양이</b> 귤 급여는 가능합니다. 하지만 대부분의 <b>고양이</b>는...
# --------------------------------------------------

# %% [markdown]
# ### 이미지 검색
# [이미지 API 문서 링크](https://developers.naver.com/docs/serviceapi/search/image/image.md#%EC%9D%B4%EB%AF%B8%EC%A7%80)
#
# (1) 기본 요청 받기

# %%
# requests 라이브러리 임포트
import requests
from urllib.parse import quote
import time
import re

# 검색어 설정 및 UTF-8 인코딩
search_query = "고양이"

# API 기본 URL (이미지 검색 URL)
base_url = "https://openapi.naver.com/v1/search/image"

# API 요청 헤더 설정
headers = {
    "X-Naver-Client-Id": client_id,
    "X-Naver-Client-Secret": client_secret
}

# API 요청 파라미터 설정
params = {
    "query": search_query,     # 검색어 (필수)
    "display": 20,             # 검색 결과 출력 건수 (기본값: 10, 최대: 100)
    "start": 1,                # 검색 시작 위치 (기본값: 1, 최대: 1000)
    "sort": "sim",             # 정렬 방식 - sim: 정확도순, date: 날짜순
    "filter": "small"          # 이미지 크기 필터 - all, large, medium, small
}

# GET 요청 보내기
response = requests.get( # 한글 자동으로 UTF-8인코딩 함
    base_url,
    headers=headers,
    params=params
)

# 응답 상태 코드 확인 및 결과 출력
if response.status_code == 200:
    # JSON 형식으로 응답 데이터 파싱
    result = response.json()
    
    # 검색어 및 전체 검색 결과 수 출력
    print(f"검색어: {search_query}")
    print(f"총 검색 결과: {result['total']} 건")
    print(f"현재 페이지: {params['start']} / {result['total']}")
    print("-" * 50)
    
    # 검색 결과 출력
    for index, item in enumerate(result.get('items', []), 1):
        print(f"[이미지 {index}]")
        print(f"제목: {item['title'].replace('<b>', '').replace('</b>', '')}")
        print(f"썸네일 URL: {item['thumbnail']}")
        print(f"원본 이미지 URL: {item['link']}")
        print(f"이미지 크기: {item['sizewidth']}x{item['sizeheight']}")
        print("-" * 50)

else:
    # 에러 발생시 상태 코드와 에러 메시지 출력
    print(f"Error Code: {response.status_code}")
    print(f"Error Message: {response.text}")
# Out:
# 검색어: 고양이
# 총 검색 결과: 685573 건
# 현재 페이지: 1 / 685573
# --------------------------------------------------
# [이미지 1]
# 제목: 영화 '와일드 로봇'처럼 동물의 특성 쏙쏙 빼낸 기기들... 고양이 눈 본뜬 카메라로 찰칵
# 썸네일 URL: https://search.pstatic.net/common/?type=b150&src=http://imgnews.naver.net/image/5557/2024/10/10/0000017176_002_20241010112615884.jpg
# 원본 이미지 URL: http://imgnews.naver.net/image/5557/2024/10/10/0000017176_002_20241010112615884.jpg
# 이미지 크기: 450x300
# --------------------------------------------------
# [이미지 2]
# 제목: 재미있는 붉은 푹신한 새끼 고양이와 크리스마스 공, 재미있는 붉은 푹신한 새끼 고양이, 크리스마스 공, 주방 배경 일러스트 및 사진 무료...
# 썸네일 URL: https://search.pstatic.net/sunny/?type=b150&src=https://png.pngtree.com/thumb_back/fh260/background/20250228/pngtree-a-small-kitten-peeking-out-of-blue-gift-box-with-ribbon-image_17035487.jpg
# 원본 이미지 URL: https://png.pngtree.com/thumb_back/fh260/background/20250228/pngtree-a-small-kitten-peeking-out-of-blue-gift-box-with-ribbon-image_17035487.jpg
# 이미지 크기: 360x360
# --------------------------------------------------
# [이미지 3]
# 제목: 바구니 고양이 1P 인테리어 소품 장식인형
# 썸네일 URL: https://search.pstatic.net/common/?type=b150&src=http://shopping.phinf.naver.net/main_4538062/45380627613.20240121212203.jpg
# 원본 이미지 URL: http://shopping.phinf.naver.net/main_4538062/45380627613.20240121212203.jpg
# 이미지 크기: 300x300
# --------------------------------------------------
# [이미지 4]
# 제목: 고양이 볼살 만지기gif
# 썸네일 URL: https://search.pstatic.net/sunny/?type=b150&src=https://i2.ruliweb.com/ori/22/11/15/1847b21ac492f0c59.gif
# 원본 이미지 URL: https://i2.ruliweb.com/ori/22/11/15/1847b21ac492f0c59.gif
# 이미지 크기: 280x280
# --------------------------------------------------
# [이미지 5]
# 제목: 고양이 동공 - 유머 / 재미 / 감동 - 네모판 고양이 동공
# 썸네일 URL: https://search.pstatic.net/sunny/?type=b150&src=https://www.nemopan.com/files/attach/images/166591/800/220/015/f4d123ad8fe763869aa295f9a0cfcfc4.gif
# 원본 이미지 URL: https://www.nemopan.com/files/attach/images/166591/800/220/015/f4d123ad8fe763869aa295f9a0cfcfc4.gif
# 이미지 크기: 250x247
# --------------------------------------------------
# [이미지 6]
# 제목: [페티오] 고양이 밥그릇 - 쏟아짐 방지 식기 웻푸드용 세라믹 : 와우한빛
# 썸네일 URL: https://search.pstatic.net/common/?type=b150&src=http://shop1.phinf.naver.net/20241010_237/1728547823570AwWpw_JPEG/62680680692235884_1699258297.jpg
# 원본 이미지 URL: http://shop1.phinf.naver.net/20241010_237/1728547823570AwWpw_JPEG/62680680692235884_1699258297.jpg
# 이미지 크기: 344x344
# --------------------------------------------------
# [이미지 7]
# 제목: 명상고양이 요가 고양이 장식 인형 조각상 인테리어소품-스타일1
# 썸네일 URL: https://search.pstatic.net/common/?type=b150&src=http://shopping.phinf.naver.net/main_5303415/53034158660.20250216011332.jpg
# 원본 이미지 URL: http://shopping.phinf.naver.net/main_5303415/53034158660.20250216011332.jpg
# 이미지 크기: 300x300
# --------------------------------------------------
# [이미지 8]
# 제목: 빌라 집 문 고양이 녹색 식물 배경 자료, 식물, 녹색 식물, 고양이 배경 일러스트 및 사진 무료 다운로드 - Pngtree
# 썸네일 URL: https://search.pstatic.net/sunny/?type=b150&src=https://png.pngtree.com/thumb_back/fh260/background/20231114/pngtree-cute-maine-coon-cat-at-home-near-christmas-tree-with-gifts-image_14006853.jpg
# 원본 이미지 URL: https://png.pngtree.com/thumb_back/fh260/background/20231114/pngtree-cute-maine-coon-cat-at-home-near-christmas-tree-with-gifts-image_14006853.jpg
# 이미지 크기: 347x260
# --------------------------------------------------
# [이미지 9]
# 제목: ChellyJelly 미국 고양이인형 ragdoll 앙고라 랙돌인형
# 썸네일 URL: https://search.pstatic.net/common/?type=b150&src=http://shopping.phinf.naver.net/main_5069083/50690833301.20241005234926.jpg
# 원본 이미지 URL: http://shopping.phinf.naver.net/main_5069083/50690833301.20241005234926.jpg
# 이미지 크기: 300x300
# --------------------------------------------------
# [이미지 10]
# 제목: 미니어처데코 인테리어장식품 미니 컵속의 고양이
# 썸네일 URL: https://search.pstatic.net/common/?type=b150&src=http://shopping.phinf.naver.net/main_5358640/53586406434.20250316235059.jpg
# 원본 이미지 URL: http://shopping.phinf.naver.net/main_5358640/53586406434.20250316235059.jpg
# 이미지 크기: 300x300
# --------------------------------------------------
# [이미지 11]
# 제목: 미드라 고양이 손가락 마사지 장난감 고양이장갑 실리콘손모양냥이토이 실리콘미니핑거장난감 실리콘손가락
# 썸네일 URL: https://search.pstatic.net/common/?type=b150&src=http://shopping.phinf.naver.net/main_5664401/56644017975.20250908214151.jpg
# 원본 이미지 URL: http://shopping.phinf.naver.net/main_5664401/56644017975.20250908214151.jpg
# 이미지 크기: 300x300
# --------------------------------------------------
# [이미지 12]
# 제목: ㄴ고양이 때문임 | (백업)유머 게시판(2018-2020) ㄴ고양이 때문임 | (백업)유머 게시판(2018-2020) | 루리웹
# 썸네일 URL: https://search.pstatic.net/sunny/?type=b150&src=https://i2.ruliweb.net/ori/20/04/01/17135a90ec5226290.gif
# 원본 이미지 URL: https://i2.ruliweb.net/ori/20/04/01/17135a90ec5226290.gif
# 이미지 크기: 300x293
# --------------------------------------------------
# [이미지 13]
# 제목: 평판형화장실 고양이 반려묘 청소가 간단한 오픈형 손잡이 화장실 + 모래삽, 1개 : 곤곤몰
# 썸네일 URL: https://search.pstatic.net/common/?type=b150&src=http://shop1.phinf.naver.net/20250923_227/1758590743232zzYtt_PNG/21578974370200331_1061728636.png
# 원본 이미지 URL: http://shop1.phinf.naver.net/20250923_227/1758590743232zzYtt_PNG/21578974370200331_1061728636.png
# 이미지 크기: 387x388
# --------------------------------------------------
# [이미지 14]
# 제목: 강아지 고양이 반려 동물 안전 가드 발톱깍이 파일
# 썸네일 URL: https://search.pstatic.net/common/?type=b150&src=http://shopping.phinf.naver.net/main_5259820/52598208793.20250121205617.jpg
# 원본 이미지 URL: http://shopping.phinf.naver.net/main_5259820/52598208793.20250121205617.jpg
# 이미지 크기: 300x300
# --------------------------------------------------
# [이미지 15]
# 제목: 고양이 반려동물 휴식 윈도우 해먹 해먹 튼튼 대형 고양이 25kg
# 썸네일 URL: https://search.pstatic.net/common/?type=b150&src=http://shopping.phinf.naver.net/main_5514022/55140227945.20250605211309.jpg
# 원본 이미지 URL: http://shopping.phinf.naver.net/main_5514022/55140227945.20250605211309.jpg
# 이미지 크기: 300x300
# --------------------------------------------------
# [이미지 16]
# 제목: 고양이는 사랑하는 사람에게 눈인사 한다는데
# 썸네일 URL: https://search.pstatic.net/sunny/?type=b150&src=https://i3.ruliweb.com/ori/22/04/18/1803c1c9b3b1316e8.gif
# 원본 이미지 URL: https://i3.ruliweb.com/ori/22/04/18/1803c1c9b3b1316e8.gif
# 이미지 크기: 256x320
# --------------------------------------------------
# [이미지 17]
# 제목: 어떻게 고양이 이름이 라인하르트 ㅋㅋㅋㅋㅋ
# 썸네일 URL: https://search.pstatic.net/sunny/?type=b150&src=https://i3.ruliweb.com/ori/22/10/01/18391b726d85267d8.gif
# 원본 이미지 URL: https://i3.ruliweb.com/ori/22/10/01/18391b726d85267d8.gif
# 이미지 크기: 250x444
# --------------------------------------------------
# [이미지 18]
# 제목: 고양이 스크래쳐 장난감 선인장 벽걸이 털손질 발톱 휴식 놀이 털갈이 애묘 : 모아담몰
# 썸네일 URL: https://search.pstatic.net/common/?type=b150&src=https://shop-phinf.pstatic.net/20250909_157/1757364925939L2Blp_JPEG/33767380071606885_249053139.jpg
# 원본 이미지 URL: https://shop-phinf.pstatic.net/20250909_157/1757364925939L2Blp_JPEG/33767380071606885_249053139.jpg
# 이미지 크기: 380x380
# --------------------------------------------------
# [이미지 19]
# 제목: 도넛 쿠션 강아지 고양이 보호대 넥카라 깔대기
# 썸네일 URL: https://search.pstatic.net/common/?type=b150&src=http://shopping.phinf.naver.net/main_5432914/54329142677.20250421221245.jpg
# 원본 이미지 URL: http://shopping.phinf.naver.net/main_5432914/54329142677.20250421221245.jpg
# 이미지 크기: 300x300
# --------------------------------------------------
# [이미지 20]
# 제목:   [신간] 딩동∼고양이 도감―저자 김태환 수의사
# 썸네일 URL: https://search.pstatic.net/common/?type=b150&src=http://imgnews.naver.net/image/5392/2018/06/04/0000006912_001_20180604190645084.jpg
# 원본 이미지 URL: http://imgnews.naver.net/image/5392/2018/06/04/0000006912_001_20180604190645084.jpg
# 이미지 크기: 300x398
# --------------------------------------------------

# %% [markdown]
# (2) 이미지 다운로드

# %%
def get_filename(filename):
    """파일명에 사용할 수 없는 특수문자를 제거하는 함수"""
    # Windows에서 파일명으로 사용할 수 없는 문자들을 제거 또는 대체
    return re.sub(r'[\\/:*?"<>|]', '', filename)

def download_image(url, folder_path, filename):
    """이미지를 다운로드하는 함수"""
    try:
        response = requests.get(url, stream=True, timeout=10)
        if response.status_code == 200:
            # 파일 확장자 추출 (없으면 .jpg로 기본 설정)
            content_type = response.headers.get('content-type', '')
            if 'jpeg' in content_type or 'jpg' in content_type:
                ext = '.jpg'
            elif 'png' in content_type:
                ext = '.png'
            elif 'gif' in content_type:
                ext = '.gif'
            else:
                ext = '.jpg'

            # 최종 파일 경로 생성
            final_path = os.path.join(folder_path, f"{filename}{ext}")
            
            # 이미지 저장
            with open(final_path, 'wb') as f:
                for chunk in response.iter_content(chunk_size=8192):
                    if chunk:
                        f.write(chunk)
            return True, final_path
        return False, "HTTP Error: " + str(response.status_code)
    except Exception as e:
        return False, str(e)

# 검색어 설정 및 UTF-8 인코딩
search_query = "고양이"

# 검색 결과 저장을 위한 폴더 생성
base_folder = "downloaded_images"
folder_path = os.path.join(base_folder, search_query)

# 폴더가 없으면 생성
os.makedirs(folder_path, exist_ok=True)

# API 기본 URL (이미지 검색 URL)
base_url = "https://openapi.naver.com/v1/search/image"

# API 요청 헤더 설정
headers = {
    "X-Naver-Client-Id": client_id,
    "X-Naver-Client-Secret": client_secret
}

# API 요청 파라미터 설정
params = {
    "query": search_query,     # 검색어 (필수)
    "display": 30,             # 검색 결과 출력 건수 (기본값: 10, 최대: 100)
    "start": 1,                # 검색 시작 위치 (기본값: 1, 최대: 1000)
    "sort": "sim",             # 정렬 방식 - sim: 정확도순, date: 날짜순
    "filter": "medium"          # 이미지 크기 필터 - all, large, medium, small
}

# GET 요청 보내기
response = requests.get(
    base_url,
    headers=headers,
    params=params
)

# 다운로드 결과 통계
download_stats = {
    'success': 0,
    'failed': 0,
    'total': 0
}

# 응답 상태 코드 확인 및 결과 출력
if response.status_code == 200:
    # JSON 형식으로 응답 데이터 파싱
    result = response.json()
    
    print(f"검색어: {search_query}")
    print(f"총 검색 결과: {result['total']} 건")
    print(f"다운로드 폴더: {folder_path}")
    print("-" * 50)
    
    # 검색 결과 처리 및 이미지 다운로드
    for index, item in enumerate(result.get('items', []), 1):
        print(f"[이미지 {index}/{len(result['items'])}] 다운로드 중...")
        print(f"제목: {item['title'].replace('<b>', '').replace('</b>', '')}")
        
        # 파일명 생성 (제목 + 인덱스)
        title_part = get_filename(item['title'][:50].replace('<b>', '').replace('</b>', ''))
        filename = f"{index:03d}_{title_part}"
        
        # 이미지 다운로드 시도
        success, message = download_image(item['link'], folder_path, filename)
        
        if success:
            print(f"다운로드 완료: {message}")
            download_stats['success'] += 1
        else:
            print(f"다운로드 실패: {message}")
            download_stats['failed'] += 1
        
        download_stats['total'] += 1
        print("-" * 50)
        
        # 네이버 서버 부하 방지를 위한 딜레이
        time.sleep(0.1)

    # 다운로드 통계 출력
    print("\n[다운로드 완료 통계]")
    print(f"성공: {download_stats['success']} 건")
    print(f"실패: {download_stats['failed']} 건")
    print(f"총 시도: {download_stats['total']} 건")
    print(f"성공률: {(download_stats['success']/download_stats['total']*100):.1f}%")
    print(f"\n이미지 저장 위치: {folder_path}")

else:
    # 에러 코드 및 메시지 출력
    error_codes = {
        400: "SE01: 잘못된 쿼리요청입니다.",
        403: "API 권한이 없습니다. 개발자 센터에서 API 권한을 확인하세요.",
        404: "SE05: 존재하지 않는 검색 API입니다.",
        500: "SE99: 시스템 에러"
    }
    
    error_message = error_codes.get(response.status_code, "알 수 없는 에러가 발생했습니다.")
    print(f"Error Code: {response.status_code}")
    print(f"Error Message: {error_message}")
    print(f"서버 응답: {response.text}")
# Out:
# 검색어: 고양이
# 총 검색 결과: 4240055 건
# 다운로드 폴더: downloaded_images\고양이
# --------------------------------------------------
# [이미지 1/30] 다운로드 중...
# 제목: 야옹 고양이 생활 시뮬레이터 - Google Play 앱
# 다운로드 완료: downloaded_images\고양이\001_야옹 고양이 생활 시뮬레이터 - Google Play 앱.png
# --------------------------------------------------
# [이미지 2/30] 다운로드 중...
# 제목: 8 페이지 | 고양이 png 사진 - 무료 고품질 사진 다운로드 | Freepik
# 다운로드 완료: downloaded_images\고양이\002_8 페이지  고양이 png 사진 - 무료 고품질 사진 다운로드  Freepik.jpg
# --------------------------------------------------
# [이미지 3/30] 다운로드 중...
# 제목: 코 짧고 납작한 '이 고양이', 각막염 위험 더 높아요 [멍멍냥냥]
# 다운로드 완료: downloaded_images\고양이\003_코 짧고 납작한 '이 고양이', 각막염 위험 더 높아요 [멍멍냥냥].jpg
# --------------------------------------------------
# [이미지 4/30] 다운로드 중...
# 제목: Birman 고양이, 10 주 오래 된, 흰색 배경 앞에 앉아 — 스톡... lifeonwhite #10895170 Birman 고양이, 10 주 오래 된, 흰색 배경 앞에 앉아
# 다운로드 완료: downloaded_images\고양이\004_Birman 고양이, 10 주 오래 된, 흰색 배경 앞에 앉아 — 스톡... lifeonw.jpg
# --------------------------------------------------
# [이미지 5/30] 다운로드 중...
# 제목: 머스펫솝 냥보리 오리지널 고양이비누 고양이샴푸 캣닢 비누 - 비누 | 쿠팡
# 다운로드 완료: downloaded_images\고양이\005_머스펫솝 냥보리 오리지널 고양이비누 고양이샴푸 캣닢 비누 - 비누  쿠팡.png
# --------------------------------------------------
# [이미지 6/30] 다운로드 중...
# 제목: 동물 고양이 시베리아 숲 새끼를 - Pixabay의 무료 사진
# 다운로드 완료: downloaded_images\고양이\006_동물 고양이 시베리아 숲 새끼를 - Pixabay의 무료 사진.jpg
# --------------------------------------------------
# [이미지 7/30] 다운로드 중...
# 제목: 노란색 배경에 털 많은 고양이의 매력적인 가족 · 무료 스톡 사진 Layan AbdulSamad님의 사진, 출처: Pexels
# 다운로드 완료: downloaded_images\고양이\007_노란색 배경에 털 많은 고양이의 매력적인 가족 · 무료 스톡 사진 Layan AbdulSa.jpg
# --------------------------------------------------
# [이미지 8/30] 다운로드 중...
# 제목: 풀을 먹는 고양이 — 스톡 사진 © Studiobarcelona #49583029 풀을 먹는 고양이
# 다운로드 완료: downloaded_images\고양이\008_풀을 먹는 고양이 — 스톡 사진 © Studiobarcelona #49583029 풀을 먹.jpg
# --------------------------------------------------
# [이미지 9/30] 다운로드 중...
# 제목: 단순한 플랫 스타일의 고양이 이모티콘 세트입니다. 로열티 무료... Image 112299253 단순한 플랫 스타일의 고양이 이모티콘 세트입니다.
# 다운로드 완료: downloaded_images\고양이\009_단순한 플랫 스타일의 고양이 이모티콘 세트입니다. 로열티 무료... Image 112299.jpg
# --------------------------------------------------
# [이미지 10/30] 다운로드 중...
# 제목: 고양이 사진 및 이미지 | Canva
# 다운로드 완료: downloaded_images\고양이\010_고양이 사진 및 이미지  Canva.png
# --------------------------------------------------
# [이미지 11/30] 다운로드 중...
# 제목: 고양이 — 스톡 사진 © Baoooo #1729979 고양이
# 다운로드 완료: downloaded_images\고양이\011_고양이 — 스톡 사진 © Baoooo #1729979 고양이.jpg
# --------------------------------------------------
# [이미지 12/30] 다운로드 중...
# 제목: 4 개의 작은 고양이 정원 — 스톡 사진 © katia26 #18086187 4 개의 작은 고양이 정원
# 다운로드 완료: downloaded_images\고양이\012_4 개의 작은 고양이 정원 — 스톡 사진 © katia26 #18086187 4 개의 작은.jpg
# --------------------------------------------------
# [이미지 13/30] 다운로드 중...
# 제목: 고양이 선인장 스크래쳐 볼 캣 장난감 : 댕냥아놀자
# 다운로드 완료: downloaded_images\고양이\013_고양이 선인장 스크래쳐 볼 캣 장난감  댕냥아놀자.jpg
# --------------------------------------------------
# [이미지 14/30] 다운로드 중...
# 제목: [마지막할인]무료배송 / 얼굴선택!고양이인식표 목걸이 : 뮤움쥬얼리
# 다운로드 완료: downloaded_images\고양이\014_[마지막할인]무료배송  얼굴선택!고양이인식표 목걸이  뮤움쥬얼리.jpg
# --------------------------------------------------
# [이미지 15/30] 다운로드 중...
# 제목: 아기 고양이 사진 및 이미지 | Canva
# 다운로드 완료: downloaded_images\고양이\015_아기 고양이 사진 및 이미지  Canva.jpg
# --------------------------------------------------
# [이미지 16/30] 다운로드 중...
# 제목: 같이 먹자고? 너 누군데? 나 고양이인데! 다묘 가정의 평화 레시피
# 다운로드 완료: downloaded_images\고양이\016_같이 먹자고 너 누군데 나 고양이인데! 다묘 가정의 평화 레시피.jpg
# --------------------------------------------------
# [이미지 17/30] 다운로드 중...
# 제목: 네이버 인플루언서 [네이버 인플루언서] 고양이 귀에 이게 뭐야?!?!?
# 다운로드 완료: downloaded_images\고양이\017_네이버 인플루언서 [네이버 인플루언서] 고양이 귀에 이게 뭐야!!.png
# --------------------------------------------------
# [이미지 18/30] 다운로드 중...
# 제목: 새끼 고양이 — 스톡 사진 © Photolin #6437546 새끼 고양이
# 다운로드 완료: downloaded_images\고양이\018_새끼 고양이 — 스톡 사진 © Photolin #6437546 새끼 고양이.jpg
# --------------------------------------------------
# [이미지 19/30] 다운로드 중...
# 제목: 고양이 — 스톡 사진 © vladvitek #34677263 고양이
# 다운로드 완료: downloaded_images\고양이\019_고양이 — 스톡 사진 © vladvitek #34677263 고양이.jpg
# --------------------------------------------------
# [이미지 20/30] 다운로드 중...
# 제목: 네이버 인플루언서 [네이버 인플루언서] 고양이 귀 염증일때 증상
# 다운로드 완료: downloaded_images\고양이\020_네이버 인플루언서 [네이버 인플루언서] 고양이 귀 염증일때 증상.png
# --------------------------------------------------
# [이미지 21/30] 다운로드 중...
# 제목: 캐티맨 고양이 어항 숨숨집 투명 캡슐 아크릴 냥이하우스 : 리타모르
# 다운로드 완료: downloaded_images\고양이\021_캐티맨 고양이 어항 숨숨집 투명 캡슐 아크릴 냥이하우스  리타모르.jpg
# --------------------------------------------------
# [이미지 22/30] 다운로드 중...
# 제목: 김씨네 고양이 Kim's Cat - YouTube 김씨네 고양이 Kim's Cat
# 다운로드 완료: downloaded_images\고양이\022_김씨네 고양이 Kim's Cat - YouTube 김씨네 고양이 Kim's Cat.jpg
# --------------------------------------------------
# [이미지 23/30] 다운로드 중...
# 제목: 스튜디오에서 벵골 고양이 | 프리미엄 사진
# 다운로드 완료: downloaded_images\고양이\023_스튜디오에서 벵골 고양이  프리미엄 사진.jpg
# --------------------------------------------------
# [이미지 24/30] 다운로드 중...
# 제목: 우리집 고양이 증명사진
# 다운로드 완료: downloaded_images\고양이\024_우리집 고양이 증명사진.jpg
# --------------------------------------------------
# [이미지 25/30] 다운로드 중...
# 제목: 언유즈얼 강아지가발 고양이 소품 단발 사진촬영소품 애견용품 애완
# 다운로드 완료: downloaded_images\고양이\025_언유즈얼 강아지가발 고양이 소품 단발 사진촬영소품 애견용품 애완.jpg
# --------------------------------------------------
# [이미지 26/30] 다운로드 중...
# 제목: 고양이 나무 - Pixabay의 무료 사진
# 다운로드 완료: downloaded_images\고양이\026_고양이 나무 - Pixabay의 무료 사진.jpg
# --------------------------------------------------
# [이미지 27/30] 다운로드 중...
# 제목: 귀여운 고양이 — 스톡 사진 © DenisNata #7535359 귀여운 고양이
# 다운로드 완료: downloaded_images\고양이\027_귀여운 고양이 — 스톡 사진 © DenisNata #7535359 귀여운 고양이.jpg
# --------------------------------------------------
# [이미지 28/30] 다운로드 중...
# 제목: 네이버 인플루언서 [네이버 인플루언서] 고양이 꿈 해몽 모음집
# 다운로드 완료: downloaded_images\고양이\028_네이버 인플루언서 [네이버 인플루언서] 고양이 꿈 해몽 모음집.png
# --------------------------------------------------
# [이미지 29/30] 다운로드 중...
# 제목: 고양이 호기심자극 장난감 반려묘 비닐공, 고양이바스락공, 1개 - 볼 | 쿠팡
# 다운로드 완료: downloaded_images\고양이\029_고양이 호기심자극 장난감 반려묘 비닐공, 고양이바스락공, 1개 - 볼  쿠팡.jpg
# --------------------------------------------------
# [이미지 30/30] 다운로드 중...
# 제목: 슬로우케어 고양이 하네스 색상선택 야외산책필수템 하네스-블루M 1개
# 다운로드 완료: downloaded_images\고양이\030_슬로우케어 고양이 하네스 색상선택 야외산책필수템 하네스-블루M 1개.png
# --------------------------------------------------
#
# [다운로드 완료 통계]
# 성공: 30 건
# 실패: 0 건
# 총 시도: 30 건
# 성공률: 100.0%
#
# 이미지 저장 위치: downloaded_images\고양이
