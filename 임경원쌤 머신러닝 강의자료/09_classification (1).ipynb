# %% [markdown]
# # 분류란?

# %% [markdown]
# ## 데이터를 보고 어느 그룹에 속하는지 라벨을 붙이는 작업

# %% [markdown]
# ## KNN
# ## 로직스틱 회귀
# ## 결정 트리

# %% [markdown]
# ## 금융사기, 스팸메일이냐 아니냐 분류작업 자동으로 해주는 아이

# %% [markdown]
# ## 마케팅, 이미지 인식(고양이냐 강아지냐, 수강생분들이냐)

# %% [markdown]
# ## 암환자
